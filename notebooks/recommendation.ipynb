# %%
import pandas as pd
from source.recommender import Recommender

# %%
df = pd.read_csv("../data/dataset.csv")
recommender_sys = Recommender(df)

# %%
songs = recommender_sys.recommend([('ヨルシカ', 'だから僕は音楽を辞めた')]) # ヨルシカ - だから僕は音楽を辞めた
# ヨルシカ(yorushika) is an amazing Japanese music group. All of you should try listening to some of their songs. by Sky
print(songs)
# Out:
# [('ヨルシカ', 'ただ君に晴れ'), ('Marie Fredriksson', 'Rickie Lee'), ('櫻坂46', 'Plastic regret'), ('ZUTOMAYO', '消えてしまいそうです'), ('YOASOBI', '好きだ')]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams')]
# [('Taylor Swift', 'You Belong With Me (Taylor’s Version)'), ('Taylor Swift', 'Love Story'), ('Ruth B.', 'Dandelions'), ('Maroon 5;Wiz Khalifa', 'Payphone'), ('One Direction', 'Story of My Life')]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams")]
print(songs)
songs = recommender_sys.recommend(songs, random=True, top_n=10)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams')]
# [('Ruth B.', 'Dandelions'), ('Ed Sheeran;Lil Baby', '2step'), ('One Direction', 'Story of My Life'), ('Tanishk Bagchi;Zahrah S Khan;Yash Narvekar;Bappi Lahiri', 'Mere Dil Gaaye Ja (Zooby Zooby)'), ('Taylor Swift', 'Love Story')]

# %%
songs = [("Eminem", "The Real Slim Shady"),
         ("Dr. Dre;Snoop Dogg", "Still D.R.E.")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Eminem', 'The Real Slim Shady'), ('Dr. Dre;Snoop Dogg', 'Still D.R.E.')]
# [('Eminem', 'Without Me'), ('Wazir Patar;Azaad', 'Pind Da Riwaaz'), ('ZAAC;Anitta;Tyga', 'Desce Pro Play (PA PA PA)'), ('Kyan', 'Mandrake'), ('2Pac', "Lil' Homies")]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams"),
         ("Eminem", "The Real Slim Shady"),
         ("Dr. Dre;Snoop Dogg", "Still D.R.E.")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams'), ('Eminem', 'The Real Slim Shady'), ('Dr. Dre;Snoop Dogg', 'Still D.R.E.')]
# [('Taylor Swift', 'Blank Space'), ('Eminem', 'Without Me'), ('Chitharth', 'Adada Adada'), ('Justin Bieber;BloodPop®', 'Friends'), ('Daddy Yankee;Myke Towers;Jhayco', 'SÚBELE EL VOLUMEN')]

# %%
songs = [("Jay Chou", "青花瓷"),
         ("David Tao", "就是愛妳")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Jay Chou', '青花瓷'), ('David Tao', '就是愛妳')]
# [('Eric Chou', '小時候的我們'), ('Jay Chou', '園遊會'), ('Jay Chou', '龍捲風'), ('Joker Xue', '天外來物'), ('詹雅雯', '媽媽請保重')]
