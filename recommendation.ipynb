# %%
import pandas as pd
from source.recommender import Recommender

df = pd.read_csv("data/dataset.csv")
recommender_sys = Recommender(df)

# %%
songs = recommender_sys.recommend([])
print(songs)
# Out:
# No songs inputted to recommender or matched in dataset. Recommending most popular songs:
# [(('Kim Petras', 'Sam Smith'), 'Unholy (feat. Kim Petras)'), (('Bizarrap', 'Quevedo'), 'Quevedo: Bzrp Music Sessions, Vol. 52'), (('Manuel Turizo',), 'La Bachata'), (('Bad Bunny', 'Chencho Corleone'), 'Me Porto Bonito'), (('Bad Bunny',), 'Tití Me Preguntó')]

# %%
songs =
songs = recommender_sys.recommend([('ヨルシカ', 'だから僕は音楽を辞めた')]) # ヨルシカ - だから僕は音楽を辞めた
# ヨルシカ(yorushika) is an amazing Japanese music group. All of you should try listening to some of their songs. by Sky
print(songs)
# Out:
# [(('Bananarama',), 'Cruel Summer'), (('George Ezra',), 'Paradise'), (('Badshah',), 'Chamkeela Chehra'), (('The 1975',), "I'm In Love With You"), (('The Rolling Stones',), 'Dead Flowers - 2009 Mix')]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams')]
# [(('Cooltime Kids',), 'America'), (('Becky Hill', 'David Guetta', 'Ella Henderson'), 'Crazy What Love Can Do'), (('Mark Sixma',), 'Million Miles'), (('Chris James', 'Hot Shade', 'Mike Perry'), 'Dive'), (('Dewain Whitmore', 'Justin Mylo', 'Martin Garrix'), 'Burn Out (feat. Dewain Whitmore)')]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams")]
print(songs)
songs = recommender_sys.recommend(songs, random=True, top_n=10)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams')]
# [(('Mark Sixma',), 'Million Miles'), (('La Grande Sophie',), 'Missive'), (('Dewain Whitmore', 'Justin Mylo', 'Martin Garrix'), 'Burn Out (feat. Dewain Whitmore)'), (('The Rolling Stones',), 'Anybody Seen My Baby? - Remastered'), (('Becky Hill', 'David Guetta', 'Ella Henderson'), 'Crazy What Love Can Do')]

# %%
songs = [("Eminem", "The Real Slim Shady"),
         ("Dr. Dre;Snoop Dogg", "Still D.R.E.")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Eminem', 'The Real Slim Shady'), ('Dr. Dre;Snoop Dogg', 'Still D.R.E.')]
# [(('Demarco',), 'I Love My Life'), (('J Balvin', 'KEVVO'), 'Billetes Azules'), (('Charly Black', 'Greeicy', 'Sean Paul'), "Ravin'"), (('Caparezza',), 'Fuori Dal Tunnel'), (('Ardian Bujupi', 'Master HP', 'Xhensila'), 'Cika Cika')]

# %%
songs = [("Justin Bieber", "Sorry"),
         ("Taylor Swift", "Wildest Dreams"),
         ("Eminem", "The Real Slim Shady"),
         ("Dr. Dre;Snoop Dogg", "Still D.R.E.")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Justin Bieber', 'Sorry'), ('Taylor Swift', 'Wildest Dreams'), ('Eminem', 'The Real Slim Shady'), ('Dr. Dre;Snoop Dogg', 'Still D.R.E.')]
# [(('Haris', 'Lucas & Steve'), 'Perfect (feat. Haris)'), (('Anuel AA', 'Daddy Yankee', 'J Balvin', 'KAROL G', 'Ozuna'), 'China'), (('FiNCH',), 'Vokuhila'), (('Feid', 'Nacho'), '911'), (('Show Dem Camp', 'Tems'), 'Live Life')]

# %%
songs = [("Jay Chou", "青花瓷"),
         ("David Tao", "就是愛妳")]
print(songs)
songs = recommender_sys.recommend(songs)
print(songs)
# Out:
# [('Jay Chou', '青花瓷'), ('David Tao', '就是愛妳')]
# [(('Eben', 'Nathaniel Bassey'), 'No One Like You'), (('Mohit Chauhan', 'Shekhar Ravjiani', 'Shruti Pathak'), 'Tujhe Bhula Diya'), (('Louyah',), 'I Used To Care'), (('Davi Sacer',), 'Foi Deus'), (('Niranj Suresh',), 'Innalekalil')]
